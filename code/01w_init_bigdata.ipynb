# %% [markdown]
# <a href="https://colab.research.google.com/github/shaun3asfas/2026-QB-BDA-code/blob/main/code/01w_init_bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01주차 데이터 시각화 준비와 기초

# %% [markdown]
# ## 간단한 데이터 시각화
# - matplotlib 활용 데이터 시각화
# - 한글 처리

# %%
import sys
sys.version
# Out:
# '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]'

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.12/dist-packages']

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
import matplotlib as np
np.__version__
# Out:
# '3.10.0'

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 92.1 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,4))
plt.title('데이터 시각화 한글 분비와 기본 직선 그래프')
plt.plot([10, 5, 10, 30])
plt.show()

# %%
import pandas as pd
pop = pd.read_csv('popmonth.csv', encoding='cp949', index_col=0, thousands='.')
pop
# Out:
#                       2026년02월_총인구수 2026년02월_세대수  2026년02월_세대당 인구  \
# 행정구역
# 전국  (1000000000)         51,106,229   24,350,797              210
# 서울특별시  (1100000000)       9,304,129    4,512,818              206
# 부산광역시  (2600000000)       3,239,016    1,576,653              205
# 대구광역시  (2700000000)       2,351,461    1,115,161              211
# 인천광역시  (2800000000)       3,054,367    1,404,284              218
# 광주광역시  (2900000000)       1,389,235      659,087              211
# 대전광역시  (3000000000)       1,441,405      699,675              206
# 울산광역시  (3100000000)       1,089,835      499,950              218
# 세종특별자치시  (3600000000)       391,240      165,449              236
# 경기도  (4100000000)        13,742,072    6,138,755              224
# 강원특별자치도  (5100000000)     1,506,699      769,508              196
# 충청북도  (4300000000)        1,596,816      799,712              200
# 충청남도  (4400000000)        2,136,064    1,064,222              201
# ...

# %%
pop.columns
# Out:
# Index(['2026년02월_총인구수', '2026년02월_세대수', '2026년02월_세대당 인구', '2026년02월_남자 인구수',
#        '2026년02월_여자 인구수', '2026년02월_남여 비율'],
#       dtype='object')

# %%
pop.columns[2]
# Out:
# '2026년02월_세대당 인구'

# %%
pop.index
# Out:
# Index(['전국  (1000000000)', '서울특별시  (1100000000)', '부산광역시  (2600000000)',
#        '대구광역시  (2700000000)', '인천광역시  (2800000000)', '광주광역시  (2900000000)',
#        '대전광역시  (3000000000)', '울산광역시  (3100000000)', '세종특별자치시  (3600000000)',
#        '경기도  (4100000000)', '강원특별자치도  (5100000000)', '충청북도  (4300000000)',
#        '충청남도  (4400000000)', '전북특별자치도  (5200000000)', '전라남도  (4600000000)',
#        '경상북도  (4700000000)', '경상남도  (4800000000)', '제주특별자치도  (5000000000)'],
#       dtype='object', name='행정구역')

# %%
pop.index[4]
# Out:
# '인천광역시  (2800000000)'

# %%
for i in range(len(pop)):
  print(pop.index[i])
# Out:
# 전국  (1000000000)
# 서울특별시  (1100000000)
# 부산광역시  (2600000000)
# 대구광역시  (2700000000)
# 인천광역시  (2800000000)
# 광주광역시  (2900000000)
# 대전광역시  (3000000000)
# 울산광역시  (3100000000)
# 세종특별자치시  (3600000000)
# 경기도  (4100000000)
# 강원특별자치도  (5100000000)
# 충청북도  (4300000000)
# 충청남도  (4400000000)
# 전북특별자치도  (5200000000)
# 전라남도  (4600000000)
# 경상북도  (4700000000)
# 경상남도  (4800000000)
# 제주특별자치도  (5000000000)

# %%
pop.columns = ['총인구수', '세대수', '세대당인구', '남자인구수', '여자인구수', '남여비율']
pop
# Out:
#                              총인구수         세대수  세대당인구       남자인구수       여자인구수  \
# 행정구역
# 전국  (1000000000)       51,106,229  24,350,797    210  25,429,357  25,676,872
# 서울특별시  (1100000000)     9,304,129   4,512,818    206   4,482,300   4,821,829
# 부산광역시  (2600000000)     3,239,016   1,576,653    205   1,574,040   1,664,976
# 대구광역시  (2700000000)     2,351,461   1,115,161    211   1,151,654   1,199,807
# 인천광역시  (2800000000)     3,054,367   1,404,284    218   1,525,266   1,529,101
# 광주광역시  (2900000000)     1,389,235     659,087    211     685,321     703,914
# 대전광역시  (3000000000)     1,441,405     699,675    206     718,084     723,321
# 울산광역시  (3100000000)     1,089,835     499,950    218     561,965     527,870
# 세종특별자치시  (3600000000)     391,240     165,449    236     194,784     196,456
# 경기도  (4100000000)      13,742,072   6,138,755    224   6,899,712   6,842,360
# 강원특별자치도  (5100000000)   1,506,699     769,508    196     757,648     749,051
# ...

# %%
type(pop)
# Out:
# pandas.core.frame.DataFrame

# %%
[pop.index[i] for i in range(len(pop))]
# Out:
# ['전국  (1000000000)',
#  '서울특별시  (1100000000)',
#  '부산광역시  (2600000000)',
#  '대구광역시  (2700000000)',
#  '인천광역시  (2800000000)',
#  '광주광역시  (2900000000)',
#  '대전광역시  (3000000000)',
#  '울산광역시  (3100000000)',
#  '세종특별자치시  (3600000000)',
#  '경기도  (4100000000)',
#  '강원특별자치도  (5100000000)',
#  '충청북도  (4300000000)',
#  '충청남도  (4400000000)',
#  '전북특별자치도  (5200000000)',
#  '전라남도  (4600000000)',
#  '경상북도  (4700000000)',
#  '경상남도  (4800000000)',
#  '제주특별자치도  (5000000000)']

# %%
pop.index[0].split()[0]
# Out:
# '전국'

# %%
pop.index[0].split()[1]
# Out:
# '(1000000000)'

# %%
pop.index = [pop.index[i].split()[0] for i in range(len(pop))]
pop
# Out:
#              총인구수         세대수  세대당인구       남자인구수       여자인구수  남여비율
# 전국       51106229  24,350,797    210  25,429,357  25,676,872    99
# 서울특별시     9304129   4,512,818    206   4,482,300   4,821,829    93
# 부산광역시     3239016   1,576,653    205   1,574,040   1,664,976    95
# 대구광역시     2351461   1,115,161    211   1,151,654   1,199,807    96
# 인천광역시     3054367   1,404,284    218   1,525,266   1,529,101   100
# 광주광역시     1389235     659,087    211     685,321     703,914    97
# 대전광역시     1441405     699,675    206     718,084     723,321    99
# 울산광역시     1089835     499,950    218     561,965     527,870   106
# 세종특별자치시    391240     165,449    236     194,784     196,456    99
# 경기도      13742072   6,138,755    224   6,899,712   6,842,360   101
# 강원특별자치도   1506699     769,508    196     757,648     749,051   101
# 충청북도      1596816     799,712    200     813,918     782,898   104
# 충청남도      2136064   1,064,222    201   1,097,210   1,038,854   106
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5, 3))
sns.scatterplot(pop['총인구수'])
plt.xticks(rotation=90)
plt.show()

# %%
pop.sort_values('총인구수')
# Out:
#              총인구수         세대수  세대당인구       남자인구수       여자인구수  남여비율
# 세종특별자치시    391240     165,449    236     194,784     196,456    99
# 제주특별자치도    663514     315,673    210     331,526     331,988   100
# 울산광역시     1089835     499,950    218     561,965     527,870   106
# 광주광역시     1389235     659,087    211     685,321     703,914    97
# 대전광역시     1441405     699,675    206     718,084     723,321    99
# 강원특별자치도   1506699     769,508    196     757,648     749,051   101
# 충청북도      1596816     799,712    200     813,918     782,898   104
# 전북특별자치도   1721941     869,571    198     858,094     863,847    99
# 전라남도      1776547     913,568    194     897,622     878,925   102
# 충청남도      2136064   1,064,222    201   1,097,210   1,038,854   106
# 대구광역시     2351461   1,115,161    211   1,151,654   1,199,807    96
# 경상북도      2500499   1,295,998    193   1,265,562   1,234,937   102
# 인천광역시     3054367   1,404,284    218   1,525,266   1,529,101   100
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5, 3))

pop1 = pop.sort_values('총인구수')
sns.barplot(x=pop1.index, y='총인구수', data=pop1)
plt.xticks(rotation=90)
plt.show()
